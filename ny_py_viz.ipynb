# %% [markdown]
# <a href="https://colab.research.google.com/github/estridge2014/NY_bail-/blob/main/ny_py_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/data_viz/py_viz/albany_admissions.csv"
alb_df = pd.read_csv(path)
alb_df.head(1)

path2 = "/content/drive/MyDrive/Colab Notebooks/data_viz/py_viz/nyc_admissions.csv"
nyc_df = pd.read_csv(path2)
nyc_df.head()
# Out:
#   admission_date release_date   race ethnicity admission_status    charge  \
# 0     2019-05-02   2019-05-09  Black   Unknown         Pretrial  VTL 0509
# 1     2019-01-06   2019-01-24  Black   Unknown         Pretrial  VTL 0509
# 2     2019-03-29   2019-04-12  Black   Unknown         Pretrial  VTL 0509
# 3     2019-08-05   2019-09-06  Other   Unknown         Pretrial  VTL 0509
# 4     2019-07-22   2019-08-01  Black   Unknown         Pretrial  VTL 0509
#
#      severity bail_eligible
# 0  Non-Felony  Non-Eligible
# 1  Non-Felony  Non-Eligible
# 2  Non-Felony  Non-Eligible
# 3  Non-Felony  Non-Eligible
# 4  Non-Felony  Non-Eligible

# %% [markdown]
# # New Section
